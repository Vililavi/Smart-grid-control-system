# %% [markdown]
# Esimerkkikoodi

# %%
# Jos paketit ei lataudu, niin suosittelen lataamaan Anacondan ja ajamaan sillä
# Tai vaihtoehtoisesti consolissa esimerkiksi 'pip install pandas'
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt

data = {
    "X": np.arange(0,10).tolist(),
    "Y": np.arange(20, 40, 2).tolist()
}

df = pd.DataFrame(data)

plt.plot(df["X"], df["Y"])
